# %%
with open("input.txt") as file:
    data = file.read().rstrip()

# %%
# for d in data:
#     print(d)

# %%
floor = 0
position = 0

for d in data:
    if d == "(":
        floor+=1
    else:
        floor-=1
    position +=1

    if floor==-1:
        print(f"{position} is basement")
        exit
    # else:
    #     print('floor is not basement')
# Out:
# 1783 is basement
# 1785 is basement
# 1797 is basement
# 6047 is basement
