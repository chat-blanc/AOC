# %%
with open("input.txt") as file:
    data = file.read().rstrip()

# %%
up = data.count('(')
down = data.count(')')
floor = up - down
print(f"up is {up} floors, down is {down} floors, resulting floor is {floor}")
# Out:
# up is 3616 floors, down is 3384 floors, resulting floor is 232
