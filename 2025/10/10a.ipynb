# %%
data = """[.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
[...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}
[.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}"""

split_data=data.split('\n')

print(split_data)
data_light_status=[]
for x in split_data:
    print(x)
    data_light_status.append(x.split[' '])

# https://www.datacamp.com/tutorial/breadth-first-search-in-python

## deque: https://www.geeksforgeeks.org/python/deque-in-python/
# Out:
# ['[.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}', '[...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}', '[.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}']
# [.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       9 for x in split_data:
#      10     print(x)
# ---> 11     data_light_status.append(x.split[' '])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
