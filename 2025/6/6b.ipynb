# %%
import numpy as np
import re
import math

data = """123 328  51 64 
 45 64  387 23 
  6 98  215 314
*   +   *   +  """

# with open("input.txt", 'r') as f:
#    data = f.read()

data= data.split('\n')
print(data)

# for d in data:
    
#     d=d.split('')
#     print(d)


operators = data[-1]
numbers = data[0:-1]

print(operators)
print(numbers)
# Out:
# ['123 328  51 64 ', ' 45 64  387 23 ', '  6 98  215 314', '*   +   *   +  ']
# *   +   *   +
# ['123 328  51 64 ', ' 45 64  387 23 ', '  6 98  215 314']
