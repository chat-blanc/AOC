# %%
import numpy as np
import re
import math
from scipy.spatial.distance import cdist
import networkx

with open("input.txt", 'r') as f:
   data = f.read()
print(len(data))
print(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 import re
#       3 import math
# ----> 4 from scipy.spatial.distance import cdist
#       5 import networkx
#       7 with open("input.txt", 'r') as f:
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# Afstand van coördinaat tot coördinaat;
# d(p,q) = v- (p1-q1)^2 + (p2-q2)^2 + (p3-q3)^2

# %%
## upper-triangular indices ( i < j )

## Setup a mask with numpy to find the unique values
## this results in a list with all the unique values (not really, the array is still the same but we continue with the mask)
## The resulting datatype is a 1-dimensional numpy array


## we need to get the smallest 1000 values
